# %% [markdown]
# **Exercise 1:**

# %%
print ("Hello world!")
#Print('Hello world!')

#this function print hello world in the console and the error is the P is capital
# Out:
# Hello world!

# %%
print('Hello world!')
#print 'Hello world!

#This error of the code is parenthesis should be closed the hello world.
# Out:
#   File "<ipython-input-3-f9e36b1ef050>", line 1
#     print Hello world!')
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print ('Hello world!')
#print ('Hello world!)

#there is no apostrophe after the exclamation mark

# %%
print("Hello world!")
#print ("Hello world")
#there is a double quation mark it should be single

# %% [markdown]
# **Exercise 2:**

# %%
x = 43
x = x + 1
print(x)
#the output is 44 because of x is sum in 1
# Out:
# 44

# %%
x = 43
x = x + 1
print(x)
#x = 43
#x = X + 1
#print(x)
# the error because of the letter x is capital letter
