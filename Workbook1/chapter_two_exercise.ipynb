# %% [markdown]
# Exercise 1
#
# **bold text**

# %%
name = input("Enter your name: ") #prompt ther user enter the name
print('Hello', name) #print user name
# Out:
# Enter your name: andre
# Hello andre

# %% [markdown]
# **Exercise 2**

# %%
hours = float(input("Enter Hours: ")) #prompt the user enter hours
rate = float(input("Enter Rate: ")) #promp the user enter the rate
gross = hours * rate #multiply the hours and rate
print("Pay: ", gross) # print the result
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay:  96.25

# %% [markdown]
# **Exercise 3**

# %%
width = 17 # Set the value of the variable
height = 12.0 # Set the value of the variable


x1 = width//2 # Calculate the integer division of 'width' and 2, and store the result in 'x1'
x2 = width/2.0 # Calculate the float division of 'width' and 2.0, and store the result in 'x2'
x3 = height/3  # Calculate the float division of 'height' and 3, and store the result in 'x3'
x4 = 1 + 2 * 5 # Calculate the value of the expression '1 + 2 * 5', and store the result in 'x4

print ('a: ',x1,type(x1)) # Print the value of 'x1' and its type
print ('b: ',x2,type(x2)) # Print the value of 'x2' and its type
print ('c: ',x3,type(x3)) # Print the value of 'x3' and its type
print ('d: ',x4,type(x4)) # Print the value of 'x4' and its type
# Out:
# a:  8 <class 'int'>
# b:  8.5 <class 'float'>
# c:  4.0 <class 'float'>
# d:  11 <class 'int'>

# %% [markdown]
# **Exercise 4**

# %%
# Take input from the user
num = int(input("Enter a number: "))

# Calculate the square of the number
square = num * num

# Print the square of the number
print("The square of", num, "is", square)
# Out:
# Enter a number: 3
# The square of 3 is 9
